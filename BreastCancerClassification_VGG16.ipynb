# %% [markdown]
# **UEM SEMESTER PROJECT 5TH SEMESTER : BREAST CANCER CLASSIFICATION**
#
# Author Name : Rajarshi Banerjee
#
# Class and Section : 3 D
#
# Year: 3 RD Year
#
# Organisation : University of Engineering and Management, Kolkata
#
# Group ID : 113
#
# Enrollment Number : 12019009022068

# %% [markdown]
# **SYSTEM SPECIFICATIONS AND REQUIREMENTS FOR THIS PROJECT**
#
# We have used Anaconda to create a separate environment for this project with the following installed:
#
# - Tensorflow 2.8.0
# - Python 3.9
# - Numpy
# - OpenCV
# - CudaToolkit 11.3
# - cuDNN Libaries for CudaToolkit 11.3
# - Pytorch
# - Matplotlib
#
# The system that this project was run on and the models were trained had the following specifications:
#
# - CPU : AMD RYZEN 5 5600X
# - GPU : NVIDIA GEFORCE RTX 3060TI
# - RAM : 16 GB DDR4 3600 MHZ
# - STORAGE : 1TB KINGSTON NVME M.2 SSD
# - PSU : 750 GIGABYTE POWERSUPPLY

# %% [markdown]
# **BREAST CANCER CLASSIFICATION USING RBF AND A COMPARITIVE STUDY BETWEEN MODELS**
#
# **SUB PROJECT : VGG-16 IMPLEMENTATION**
#
# In this project we have classified Breast Cancer cells using rbf and we aim to implement different models and compare the accuracy on the data for the different models.
#
# The models implemented in this project are :
#
# - Custom Convolutional Neural Network
# - VGG 16
# - VGG 19
# - SVC with RBF
# - EfficientNETB0
# - EfficientNETB1
# - EfficientNETB2
# - EfficientNETB3
# - EfficientNETB4
# - EfficientNETB5
# - EfficientNETB6
# - EfficientNETB7
# - EfficientNETB8
# - EfficientNETB9

# %% [markdown]
# We start by importing the necessary libaries.
#
# - Image processes the data.
# - We start by importing ImageDataGenerator which generates multiple versions of the image by shrinking it, zooming and flipping it horizontally or vertically.
# - We then import Sequential to enable stacking of neurons.
# - Flatten converts 2D image to 1D image.
# - Dense helps in create layers.
# - VGG16 pre-constructed model from keras.models
# - Numpy is used to convert lists into arrays.
# - The glob module finds all the pathnames matching a specified pattern

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
import numpy as np
from glob import glob

# %% [markdown]
# We then specify the dimensions of the images and initialising the directory of the stored images.

# %%
IMAGE_SIZE = [224, 224]

train_path = 'Dataset_2000/train'
valid_path = 'Dataset_2000/valid'

# %% [markdown]
# Input Image size is initialised and 3 is for rgb channel
#
# Importing the VGG16 libaray as shown below and add preprocessing layer to the front of the VGG16
#
# Here we will be using the imagenet weights
#
# include_top means that we will be removing the first and the last layer. The first layer will have 224x224 from the weights, the last layer will be 1000 categories as the weights used are from imagenet, since in our custom dataset we have only two categories we remove the first and the last layer

# %%
vgg16 = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %% [markdown]
# We are using the weights from image net so no training should happen in the middle layers but only in the last layer.

# %%
for layer in vgg16.layers:
    layer.trainable = False

# %% [markdown]
# Now we find out the number of output classes

# %%
folders = glob('Dataset_2000/train/*')
folders
# Out:
# ['Dataset_2000/train\\0_NoCancer', 'Dataset_2000/train\\1_Cancer']

# %% [markdown]
# Now from the architecture it is evident that we need to flatten the layers and thus we use the Flatten function.
#
# The length of folders have been used as the output layer, which means two output categories.

# %%
x = Flatten()(vgg16.output)
prediction = Dense(len(folders), activation='sigmoid')(x)

# %% [markdown]
# **VGG 16 NEURAL NETWORK**
#
# The Model is then created. The VGG 16 architecture looks like the figure below :
#
# ![vgg.png](attachment:vgg.png)
#
# The neural network structure is as follows :
#
# - Convolutional Layer
# - Convolutional Layer
# - MaxPooling Layer
# - Convolutional Layer
# - Convolutional Layer
# - MaxPooling Layer
# - Convolutional Layer
# - Convolutional Layer
# - Convolutional Layer
# - MaxPooling Layer
# - Convolutional Layer
# - Convolutional Layer
# - Convolutional Layer
# - MaxPooling Layer
# - Convolutional Layer
# - Convolutional Layer
# - Convolutional Layer
# - MaxPooling Layer
# - Flatten layer
# - Fully connected + ReLU activation
# - Fully connected + ReLU activation
# - Fully connected + ReLU activation
# - Output layer

# %%
model = Model(inputs=vgg16.input, outputs=prediction)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 2)                 50178
#
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# The Model is then compiled with :
#
# - loss = categorical_crossentropy
# - optimizer = adam
# - metrics = accuracy

# %%
model.compile(
  loss='binary_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %% [markdown]
# Now we generate the training data. We have rescaled it, sheared it, zoomed it and horizontally flipped it. So out of one image we have generated 4 images for the training data.
#
# For the validation data, we have only rescaled it.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %% [markdown]
# Now we get the images from the respective directories

# %%
training_set = train_datagen.flow_from_directory('Dataset_2000/train',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory('Dataset_2000/valid',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.

# %% [markdown]
# Model is then trained on the training data and the accuracy is measured on both the training and the validation dataset.

# %%
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=35,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set),
  shuffle = True
)
# Out:
# C:\Users\rajar\AppData\Local\Temp\ipykernel_10192\1784854242.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   r = model.fit_generator(
# Epoch 1/35
# 63/63 [==============================] - 17s 218ms/step - loss: 0.5191 - accuracy: 0.7360 - val_loss: 0.3923 - val_accuracy: 0.8300
# Epoch 2/35
# 63/63 [==============================] - 13s 210ms/step - loss: 0.4045 - accuracy: 0.8260 - val_loss: 0.3310 - val_accuracy: 0.8625
# Epoch 3/35
# 63/63 [==============================] - 13s 207ms/step - loss: 0.3717 - accuracy: 0.8435 - val_loss: 0.3183 - val_accuracy: 0.8800
# Epoch 4/35
# 63/63 [==============================] - 13s 212ms/step - loss: 0.3345 - accuracy: 0.8590 - val_loss: 0.3073 - val_accuracy: 0.8800
# Epoch 5/35
# 63/63 [==============================] - 13s 205ms/step - loss: 0.3168 - accuracy: 0.8695 - val_loss: 0.3183 - val_accuracy: 0.8650
# Epoch 6/35
# 63/63 [==============================] - 13s 205ms/step - loss: 0.3133 - accuracy: 0.8795 - val_loss: 0.3256 - val_accuracy: 0.8575
# Epoch 7/35
# 63/63 [==============================] - 13s 206ms/step - loss: 0.3096 - accuracy: 0.8725 - val_loss: 0.3192 - val_accuracy: 0.8825
# Epoch 8/35
# 63/63 [==============================] - 13s 206ms/step - loss: 0.2886 - accuracy: 0.8880 - val_loss: 0.3260 - val_accuracy: 0.8700
# Epoch 9/35
# 63/63 [==============================] - 13s 206ms/step - loss: 0.2602 - accuracy: 0.8975 - val_loss: 0.3127 - val_accuracy: 0.8775
# Epoch 10/35
# 63/63 [==============================] - 13s 207ms/step - loss: 0.2795 - accuracy: 0.8815 - val_loss: 0.3411 - val_accuracy: 0.8625
# Epoch 11/35
# 63/63 [==============================] - 13s 207ms/step - loss: 0.2638 - accuracy: 0.8995 - val_loss: 0.3295 - val_accuracy: 0.8700
# Epoch 12/35
# 63/63 [==============================] - 13s 208ms/step - loss: 0.2536 - accuracy: 0.9055 - val_loss: 0.3153 - val_accuracy: 0.8650
# Epoch 13/35
# 63/63 [==============================] - 13s 206ms/step - loss: 0.2408 - accuracy: 0.9080 - val_loss: 0.3231 - val_accuracy: 0.8625
# Epoch 14/35
# 63/63 [==============================] - 13s 204ms/step - loss: 0.2459 - accuracy: 0.9070 - val_loss: 0.3591 - val_accuracy: 0.8625
# Epoch 15/35
# 63/63 [==============================] - 13s 204ms/step - loss: 0.2254 - accuracy: 0.9135 - val_loss: 0.3653 - val_accuracy: 0.8525
# Epoch 16/35
# 63/63 [==============================] - 13s 204ms/step - loss: 0.2340 - accuracy: 0.9030 - val_loss: 0.3191 - val_accuracy: 0.8600
# Epoch 17/35
# 63/63 [==============================] - 13s 210ms/step - loss: 0.2208 - accuracy: 0.9160 - val_loss: 0.3153 - val_accuracy: 0.8775
# Epoch 18/35
# 63/63 [==============================] - 13s 208ms/step - loss: 0.2174 - accuracy: 0.9135 - val_loss: 0.3287 - val_accuracy: 0.8700
# Epoch 19/35
# 63/63 [==============================] - 13s 208ms/step - loss: 0.2054 - accuracy: 0.9205 - val_loss: 0.3199 - val_accuracy: 0.8700
# Epoch 20/35
# 63/63 [==============================] - 13s 208ms/step - loss: 0.2126 - accuracy: 0.9205 - val_loss: 0.3693 - val_accuracy: 0.8475
# Epoch 21/35
# 63/63 [==============================] - 13s 209ms/step - loss: 0.2056 - accuracy: 0.9205 - val_loss: 0.3200 - val_accuracy: 0.8725
# Epoch 22/35
# 63/63 [==============================] - 13s 209ms/step - loss: 0.2190 - accuracy: 0.9125 - val_loss: 0.3282 - val_accuracy: 0.8625
# Epoch 23/35
# 63/63 [==============================] - 13s 205ms/step - loss: 0.1944 - accuracy: 0.9240 - val_loss: 0.3416 - val_accuracy: 0.8525
# Epoch 24/35
# 63/63 [==============================] - 13s 205ms/step - loss: 0.1868 - accuracy: 0.9345 - val_loss: 0.3410 - val_accuracy: 0.8500
# Epoch 25/35
# 63/63 [==============================] - 13s 204ms/step - loss: 0.1881 - accuracy: 0.9350 - val_loss: 0.3550 - val_accuracy: 0.8550
# Epoch 26/35
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1904 - accuracy: 0.9350 - val_loss: 0.3747 - val_accuracy: 0.8525
# Epoch 27/35
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1898 - accuracy: 0.9235 - val_loss: 0.3308 - val_accuracy: 0.8625
# Epoch 28/35
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1973 - accuracy: 0.9260 - val_loss: 0.3460 - val_accuracy: 0.8600
# Epoch 29/35
# 63/63 [==============================] - 13s 207ms/step - loss: 0.2008 - accuracy: 0.9245 - val_loss: 0.3254 - val_accuracy: 0.8675
# Epoch 30/35
# 63/63 [==============================] - 13s 210ms/step - loss: 0.1810 - accuracy: 0.9290 - val_loss: 0.3305 - val_accuracy: 0.8700
# Epoch 31/35
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1709 - accuracy: 0.9355 - val_loss: 0.3351 - val_accuracy: 0.8625
# Epoch 32/35
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1717 - accuracy: 0.9320 - val_loss: 0.3526 - val_accuracy: 0.8600
# Epoch 33/35
# 63/63 [==============================] - 13s 206ms/step - loss: 0.1517 - accuracy: 0.9405 - val_loss: 0.3498 - val_accuracy: 0.8525
# Epoch 34/35
# 63/63 [==============================] - 13s 204ms/step - loss: 0.1622 - accuracy: 0.9435 - val_loss: 0.3860 - val_accuracy: 0.8300
# Epoch 35/35
# 63/63 [==============================] - 13s 207ms/step - loss: 0.1589 - accuracy: 0.9420 - val_loss: 0.3444 - val_accuracy: 0.8525

# %% [markdown]
# Model is then evaluated on the training and validation dataset and the respective accuracy is displayed

# %%
print(model.evaluate(training_set))
print(model.evaluate(test_set))
# Out:
# 63/63 [==============================] - 12s 192ms/step - loss: 0.1487 - accuracy: 0.9495
# [0.1487116664648056, 0.9495000243186951]
# 13/13 [==============================] - 1s 72ms/step - loss: 0.3444 - accuracy: 0.8525
# [0.34444427490234375, 0.8525000214576721]

# %% [markdown]
# Now we plot the Validation and Training loss and Validation and Training Accuracy

# %%
import matplotlib.pyplot as plt

plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')
